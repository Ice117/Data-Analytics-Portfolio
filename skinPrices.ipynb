# %% [markdown]
# DENTRO DE UM LOOP :
# # 1 - Ler e juntar o nome da arma e da skin.
# # 2 - trocar os espaços por "-" para acessar os links das skins
# # 3 - achar os valores de cada float
# #  3.1 - tirar valores vazios
# 4 - registrar os valores
# 5 - Salvar

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
import time
url = "https://csgoskins.gg/items/"
navegador.get("https://csgoskins.gg")
time.sleep(3)

# %%
import pandas as pd

tabela = pd.read_excel("skinpr.xlsx")
display(tabela.loc[:,['link']])
# Out:
#                         link
# 0       AWP-Lightning-Strike
# 1      Desert-Eagle-Hypnotic
# 2        AK-47-Case-Hardened
# 3     Glock-18-Dragon-Tattoo
# 4           USP-S-Dark-Water
# ...                      ...
# 1219      PP-Bizon-Cold-Cell
# 1220     Tec-9-Tiger-Stencil
# 1221          MAG-7-Wildwood
# 1222       FAMAS-Half-Sleeve
# 1223     AK-47-Olive-Polycam
#
# [1224 rows x 1 columns]

# %%
getskin = tabela.loc[1,'link'].lower()
navegador.get(url+getskin)
print(len(tabela['link']))
# Out:
# 1224

# %%
# get link on table
for i, row in tabela.iterrows():
  # get url
  getskin = row['link'].lower()
  navegador.get(url+getskin)
  # wait for website load
  time.sleep(3)
  
  # find the the prices path
  price_list = navegador.find_element(By.XPATH, '/html/body/main/div[2]/div[1]/div[1]/div')
  prices = price_list.find_elements(By.TAG_NAME, 'a')

  #take the prices values
  for index, row in enumerate(prices, start=1):
    cells = row.find_elements(By.TAG_NAME, "span")
    cell_values = [cell.text for cell in cells]

    # verify empty values
    if cell_values:

      #verify and handle stattraks
      if len(cell_values) > 2:
        cell_values[0] += " " + cell_values[1]
        del cell_values[1]

      column_name = cell_values[0]
      price_value = cell_values[1]

      tabela.loc[i, column_name] = price_value
      print(cell_values)
# Out:
# ['Factory New', '$550.00']
# ['Minimal Wear', '$566.23']
# ['StatTrak Factory New', '$865.01']
# ['StatTrak Minimal Wear', '$895.18']
# ['Factory New', '$93.14']
# ['Minimal Wear', '$101.35']
# ['StatTrak Factory New', '$134.42']
# ['StatTrak Minimal Wear', '$163.21']
# ['Factory New', '$336.21']
# ['Minimal Wear', '$256.37']
# ['Field-Tested', '$229.00']
# ['Well-Worn', '$195.61']
# ['Battle-Scarred', '$188.78']
# ['StatTrak Factory New', '$803.43']
# ['StatTrak Minimal Wear', '$519.00']
# ['StatTrak Field-Tested', '$410.00']
# ['StatTrak Well-Worn', '$348.88']
# ['StatTrak Battle-Scarred', '$340.00']
# ['Factory New', '$95.04']
# ['Minimal Wear', '$104.78']
# ['StatTrak Factory New', '$423.24']
# ['StatTrak Minimal Wear', '$328.20']
# ['Minimal Wear', '$86.98']
# ['Field-Tested', '$78.79']
# ['StatTrak Minimal Wear', '$134.00']
# ['StatTrak Field-Tested', '$115.27']
# ['Minimal Wear', '$85.58']
# ['Field-Tested', '$78.99']
# ['StatTrak Minimal Wear', '$136.14']
# ['StatTrak Field-Tested', '$114.64']
# ['Factory New', '$24.43']
# ['Minimal Wear', '$24.97']
# ['StatTrak Factory New', '$27.64']
# ['StatTrak Minimal Wear', '$25.79']
# ['Factory New', '$37.59']
# ['Minimal Wear', '$24.00']
# ['Field-Tested', '$23.56']
# ['Well-Worn', '$23.68']
# ['Battle-Scarred', '$23.70']
# ['StatTrak Factory New', '$95.04']
# ['StatTrak Minimal Wear', '$27.95']
# ['StatTrak Field-Tested', '$26.25']
# ['StatTrak Well-Worn', '$24.76']
# ['StatTrak Battle-Scarred', '$25.03']
# ['Minimal Wear', '$23.81']
# ['Field-Tested', '$23.73']
# ['StatTrak Minimal Wear', '$26.34']
# ['StatTrak Field-Tested', '$25.76']
# ['Factory New', '$1,443.62']
# ['Minimal Wear', '$1,409.09']
# ['Factory New', '$780.00']
# ['Minimal Wear', '$248.60']
# ['Field-Tested', '$92.81']
# ['Well-Worn', '$86.44']
# ['Battle-Scarred', '$96.49']
# ['Factory New', '$388.78']
# ['Minimal Wear', '$423.70']
# ['Factory New', '$347.62']
# ['Minimal Wear', '$544.54']
# ['Factory New', '$81.54']
# ['Minimal Wear', '$78.20']
# ['Field-Tested', '$81.05']
# ['Factory New', '$44.71']
# ['Minimal Wear', '$10.57']
# ['Field-Tested', '$9.69']
# ['Well-Worn', '$13.61']
# ['Battle-Scarred', '$11.32']
# ['Factory New', '$49.04']
# ['Minimal Wear', '$11.14']
# ['Field-Tested', '$9.30']
# ['Well-Worn', '$24.80']
# ['Battle-Scarred', '$10.36']
# ['Factory New', '$1.84']
# ['Minimal Wear', '$5.32']
# ['Factory New', '$67.95']
# ['Minimal Wear', '$13.05']
# ['Field-Tested', '$8.48']
# ['Well-Worn', '$17.94']
# ['Battle-Scarred', '$7.28']
# ['Factory New', '$121.97']
# ['Minimal Wear', '$12.08']
# ['Field-Tested', '$4.67']
# ['Well-Worn', '$4.62']
# ['Battle-Scarred', '$4.22']
# ['Factory New', '$53.31']
# ['Minimal Wear', '$5.56']
# ['Field-Tested', '$1.70']
# ['Well-Worn', '$3.19']
# ['Battle-Scarred', '$1.49']
# ['Factory New', '$27.14']
# ['Minimal Wear', '$4.47']
# ['Field-Tested', '$1.96']
# ['Well-Worn', '$2.52']
# ['Battle-Scarred', '$1.77']
# ['Factory New', '$29.69']
# ['Minimal Wear', '$3.83']
# ['Field-Tested', '$1.45']
# ['Well-Worn', '$2.69']
# ['Battle-Scarred', '$1.80']
# ['Factory New', '$67.13']
# ['Minimal Wear', '$30.58']
# ['Field-Tested', '$20.14']
# ['Well-Worn', '$19.34']
# ['Battle-Scarred', '$16.73']
# ['Factory New', '$646.90']
# ['Minimal Wear', '$612.38']
# ['Factory New', '$5.64']
# ['Minimal Wear', '$14.66']
# ['Factory New', '$196.16']
# ['Minimal Wear', '$102.32']
# ['Field-Tested', '$97.27']
# ['Well-Worn', '$119.68']
# ['Battle-Scarred', '$100.18']
# ['Factory New', '$136.00']
# ['Minimal Wear', '$102.00']
# ['Field-Tested', '$103.36']
# ['Well-Worn', '$101.20']
# ['Battle-Scarred', '$125.00']
# ['Minimal Wear', '$106.77']
# ['Field-Tested', '$104.16']
# ['Factory New', '$50.80']
# ['Minimal Wear', '$19.58']
# ['Field-Tested', '$19.39']
# ['Well-Worn', '$19.02']
# ['Battle-Scarred', '$23.95']
# ['Factory New', '$59.12']
# ['Minimal Wear', '$22.00']
# ['Field-Tested', '$19.35']
# ['Well-Worn', '$18.80']
# ['Battle-Scarred', '$18.28']
# ['Factory New', '$38.54']
# ['Minimal Wear', '$20.00']
# ['Field-Tested', '$19.00']
# ['Well-Worn', '$18.65']
# ['Battle-Scarred', '$19.77']
# ['Minimal Wear', '$45.73']
# ['Field-Tested', '$35.65']
# ['StatTrak Minimal Wear', '$212.33']
# ['StatTrak Field-Tested', '$103.59']
# ['Factory New', '$414.30']
# ['Minimal Wear', '$139.45']
# ['Field-Tested', '$127.02']
# ['StatTrak Factory New', '$576.91']
# ['StatTrak Minimal Wear', '$220.00']
# ['StatTrak Field-Tested', '$172.09']
# ['Factory New', '$296.09']
# ['Minimal Wear', '$101.20']
# ['Field-Tested', '$59.07']
# ['Well-Worn', '$56.39']
# ['Battle-Scarred', '$59.47']
# ['StatTrak Factory New', '$1,099.00']
# ['StatTrak Minimal Wear', '$228.17']
# ['StatTrak Field-Tested', '$132.14']
# ['StatTrak Well-Worn', '$125.00']
# ['StatTrak Battle-Scarred', '$122.53']
# ['Factory New', '$35.00']
# ['Minimal Wear', '$23.57']
# ['Field-Tested', '$19.30']
# ['StatTrak Factory New', '$65.84']
# ['StatTrak Minimal Wear', '$36.21']
# ['StatTrak Field-Tested', '$33.15']
# ['Factory New', '$46.32']
# ['Minimal Wear', '$18.00']
# ['Field-Tested', '$16.32']
# ['Well-Worn', '$9.79']
# ['Battle-Scarred', '$11.30']
# ['StatTrak Factory New', '$184.62']
# ['StatTrak Minimal Wear', '$35.36']
# ['StatTrak Field-Tested', '$18.40']
# ['StatTrak Well-Worn', '$18.41']
# ['StatTrak Battle-Scarred', '$18.93']
# ['Factory New', '$40.98']
# ['Minimal Wear', '$19.42']
# ['Field-Tested', '$15.28']
# ['Well-Worn', '$16.69']
# ['Battle-Scarred', '$12.93']
# ['StatTrak Factory New', '$414.43']
# ['StatTrak Minimal Wear', '$33.56']
# ['StatTrak Field-Tested', '$22.00']
# ['StatTrak Well-Worn', '$22.74']
# ['StatTrak Battle-Scarred', '$19.57']
# ['Minimal Wear', '$4.10']
# ['Field-Tested', '$4.18']
# ['StatTrak Minimal Wear', '$4.45']
# ['StatTrak Field-Tested', '$4.55']
# ['Factory New', '$5.05']
# ['Minimal Wear', '$4.10']
# ['Field-Tested', '$5.47']
# ['StatTrak Factory New', '$8.11']
# ['StatTrak Minimal Wear', '$5.29']
# ['StatTrak Field-Tested', '$5.64']
# ['Factory New', '$19.03']
# ['Minimal Wear', '$5.02']
# ['Field-Tested', '$3.90']
# ['Well-Worn', '$4.17']
# ['Battle-Scarred', '$3.81']
# ['StatTrak Factory New', '$69.07']
# ['StatTrak Minimal Wear', '$6.60']
# ['StatTrak Field-Tested', '$4.16']
# ['StatTrak Well-Worn', '$4.15']
# ['StatTrak Battle-Scarred', '$4.26']
# ['Factory New', '$36.27']
# ['Minimal Wear', '$8.79']
# ['Field-Tested', '$2.73']
# ['Well-Worn', '$2.14']
# ['Battle-Scarred', '$2.42']
# ['Souvenir Factory New', '$139.52']
# ['Souvenir Minimal Wear', '$24.38']
# ['Souvenir Field-Tested', '$12.42']
# ['Souvenir Well-Worn', '$10.23']
# ['Souvenir Battle-Scarred', '$11.61']
# ['Factory New', '$1.67']
# ['Minimal Wear', '$12.15']
# ['Souvenir Factory New', '$8.52']
# ['Souvenir Minimal Wear', '$25.63']
# ['Factory New', '$164.39']
# ['Minimal Wear', '$22.83']
# ['Field-Tested', '$6.35']
# ['Well-Worn', '$5.21']
# ['Battle-Scarred', '$5.25']
# ['Souvenir Factory New', '$160.26']
# ['Souvenir Minimal Wear', '$31.54']
# ['Souvenir Field-Tested', '$10.35']
# ['Souvenir Well-Worn', '$8.70']
# ['Souvenir Battle-Scarred', '$7.66']
# ['Factory New', '$34.24']
# ['Minimal Wear', '$3.39']
# ['Field-Tested', '$2.26']
# ['Well-Worn', '$2.48']
# ['Battle-Scarred', '$2.62']
# ['Souvenir Factory New', '$41.30']
# ['Souvenir Minimal Wear', '$4.67']
# ['Souvenir Field-Tested', '$2.33']
# ['Souvenir Well-Worn', '$2.72']
# ['Souvenir Battle-Scarred', '$1.84']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 7
#       5 navegador.get(url+getskin)
#       6 # wait for website load
# ----> 7 time.sleep(3)
#       9 # find the the prices path
#      10 price_list = navegador.find_element(By.XPATH, '/html/body/main/div[2]/div[1]/div[1]/div')
#
# KeyboardInterrupt:

# %%
display(tabela)
#tabela.to_excel("skinprices.xlsx", index=False)
# Out:
#                         link        Weapon              Skin      Rarity  \
# 0       AWP-Lightning-Strike           AWP  Lightning Strike      Covert
# 1      Desert-Eagle-Hypnotic  Desert-Eagle          Hypnotic  Classified
# 2        AK-47-Case-Hardened         AK-47     Case Hardened  Classified
# 3     Glock-18-Dragon-Tattoo      Glock-18     Dragon Tattoo  Restricted
# 4           USP-S-Dark-Water         USP-S        Dark Water  Restricted
# ...                      ...           ...               ...         ...
# 1219      PP-Bizon-Cold-Cell      PP-Bizon         Cold Cell  Industrial
# 1220     Tec-9-Tiger-Stencil         Tec-9     Tiger Stencil  Industrial
# 1221          MAG-7-Wildwood         MAG-7          Wildwood  Industrial
# 1222       FAMAS-Half-Sleeve         FAMAS       Half Sleeve  Industrial
# 1223     AK-47-Olive-Polycam         AK-47     Olive Polycam  Industrial
#
#      Factory New Minimal Wear Field-Tested Well-Worn Battle-Scarred  \
# 0        $550.00      $566.23          NaN       NaN            NaN
# 1         $93.14      $101.35          NaN       NaN            NaN
# 2        $336.21      $256.37      $229.00   $195.61        $188.78
# 3         $95.04      $104.78          NaN       NaN            NaN
# 4            NaN       $86.98       $78.79       NaN            NaN
# ...          ...          ...          ...       ...            ...
# 1219         NaN          NaN          NaN       NaN            NaN
# 1220         NaN          NaN          NaN       NaN            NaN
# 1221         NaN          NaN          NaN       NaN            NaN
# 1222         NaN          NaN          NaN       NaN            NaN
# 1223         NaN          NaN          NaN       NaN            NaN
#
#      StatTrak Factory New  ... StatTrak Well-Worn StatTrak Battle-Scarred  \
# 0                 $865.01  ...                NaN                     NaN
# 1                 $134.42  ...                NaN                     NaN
# 2                 $803.43  ...            $348.88                 $340.00
# 3                 $423.24  ...                NaN                     NaN
# 4                     NaN  ...                NaN                     NaN
# ...                   ...  ...                ...                     ...
# 1219                  NaN  ...                NaN                     NaN
# 1220                  NaN  ...                NaN                     NaN
# 1221                  NaN  ...                NaN                     NaN
# 1222                  NaN  ...                NaN                     NaN
# 1223                  NaN  ...                NaN                     NaN
#
#                         Collection Case Launch Date  Souvenir Factory New  \
# 0         The Arms Deal Collection  NaN  2013-08-14                   NaN
# 1         The Arms Deal Collection  NaN  2013-08-14                   NaN
# 2         The Arms Deal Collection  NaN  2013-08-14                   NaN
# 3         The Arms Deal Collection  NaN  2013-08-14                   NaN
# 4         The Arms Deal Collection  NaN  2013-08-14                   NaN
# ...                            ...  ...         ...                   ...
# 1219  The Sport & Field Collection  NaN  2024-10-02                   NaN
# 1220  The Sport & Field Collection  NaN  2024-10-02                   NaN
# 1221  The Sport & Field Collection  NaN  2024-10-02                   NaN
# 1222  The Sport & Field Collection  NaN  2024-10-02                   NaN
# 1223  The Sport & Field Collection  NaN  2024-10-02                   NaN
#
#      Souvenir Minimal Wear Souvenir Field-Tested Souvenir Well-Worn  \
# 0                      NaN                   NaN                NaN
# 1                      NaN                   NaN                NaN
# 2                      NaN                   NaN                NaN
# 3                      NaN                   NaN                NaN
# 4                      NaN                   NaN                NaN
# ...                    ...                   ...                ...
# 1219                   NaN                   NaN                NaN
# 1220                   NaN                   NaN                NaN
# 1221                   NaN                   NaN                NaN
# 1222                   NaN                   NaN                NaN
# 1223                   NaN                   NaN                NaN
#
#      Souvenir Battle-Scarred
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 1219                     NaN
# 1220                     NaN
# 1221                     NaN
# 1222                     NaN
# 1223                     NaN
#
# [1224 rows x 22 columns]
